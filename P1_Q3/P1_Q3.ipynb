# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv ("C:\\Users\\EASY\\NextGrowthLabs Evaluation-1\\P1_Q3\\browser_rankings_data.csv")

# %%
df.shape
# Out:
# (3067, 1)

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                                                                                                                                                                     browser_rankings
# ID     Keyword         Rank Country Language Date       App ID                 Date of Last Description Change Short Description                                                                    Long Description
# 1      browser         2    in      en       2020-12-16 net.fast.web.browser   2020-12-18                      The small, fastest, secure Web Browser, best mo...  One of the smallest, fastest, secure Web Brows...
# 2      browser         3    in      en       2020-12-16 com.android.chrome     2020-12-18                      Fast, simple, and secure. Google Chrome browser...  Google Chrome is a fast, easy to use, and secu...
# ...

# %%
df.head(7)
# Out:
#                                                                                                                                                                                         browser_rankings
# ID Keyword Rank Country Language Date       App ID                 Date of Last Description Change Short Description                                                                    Long Description
# 1  browser 2    in      en       2020-12-16 net.fast.web.browser   2020-12-18                      The small, fastest, secure Web Browser, best mo...  One of the smallest, fastest, secure Web Brows...
# 2  browser 3    in      en       2020-12-16 com.android.chrome     2020-12-18                      Fast, simple, and secure. Google Chrome browser...  Google Chrome is a fast, easy to use, and secu...
# ...

# %%
df = pd.read_csv ("C:\\Users\\EASY\\NextGrowthLabs Evaluation-1\\P1_Q3\\browser_rankings_data.csv", skiprows = 1, sep=',')
df.head(5)
# Out:
#    ID  Keyword  Rank Country Language        Date                  App ID  \
# 0   1  browser   2.0      in       en  2020-12-16    net.fast.web.browser
# 1   2  browser   3.0      in       en  2020-12-16      com.android.chrome
# 2   3  browser   4.0      in       en  2020-12-16       com.opera.browser
# 3   3  browser   4.0      in       en  2020-12-16       com.opera.browser
# 4   4  browser   1.0      in       en  2020-12-16  com.cloudmosa.puffinTV
#
#   Date of Last Description Change  \
# 0                      2020-12-18
# 1                      2020-12-18
# 2                      2021-02-27
# 3                      2020-12-18
# 4                      2021-02-07
#
#                                    Short Description  \
# 0  The small, fastest, secure Web Browser, best m...
# 1  Fast, simple, and secure. Google Chrome browse...
# 2  Fast, safe web browser: free VPN, Ad blocker, ...
# 3  Fast, safe web browser: free VPN, Ad blocker, ...
# ...

# %%
df.describe()
# Out:
#                   ID         Rank
# count    3066.000000  3050.000000
# mean    57109.156230    15.155738
# std     39290.651658    24.268403
# min         1.000000     1.000000
# 25%     22484.000000     2.000000
# 50%     52427.000000     5.000000
# 75%     90683.750000    16.000000
# max    131576.000000   134.000000

# %%
df['Rank']= df['Rank'].astype('category').cat.codes
df['Long Description']= df['Long Description'].astype('category').cat.codes
df['Short Description']= df['Short Description'].astype('category').cat.codes
df.corr()
# Out:
#                          ID      Rank  Short Description  Long Description
# ID                 1.000000  0.007754          -0.002761          0.002429
# Rank               0.007754  1.000000          -0.219051          0.332171
# Short Description -0.002761 -0.219051           1.000000         -0.513976
# Long Description   0.002429  0.332171          -0.513976          1.000000

# %%
c1= df['Rank'].corr(df['Short Description'])
c2= df['Rank'].corr(df['Long Description'])
print(c1,c2)
# Out:
# -0.21905096753362738 0.33217059624990364
